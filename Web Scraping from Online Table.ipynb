# %%
# import Libraries
from bs4 import BeautifulSoup
import requests

# %%
# connect to website
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_South_Africa#2019_Forbes_list'
page = requests.get(url)
soup = BeautifulSoup(page.text,"html")
#soup2 = BeautifulSoup(soup1.prettify(), "html")



print(soup)
#print(soup2)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest companies in South Africa - Wikipedia</title>
# ...

# %%
soup.find('table')
# Out:
# <table class="wikitable sortable" style="text-align:center;">
# <tbody><tr>
# <th><br/><br/><br/>
# </th>
# <th align="center">Forbes <br/>2000 rank
# </th>
# <th align="center">Name
# </th>
# <th align="center">Headquarters
# </th>
# <th align="center">Revenue<br/>(billions <br/>US$)
# </th>
# <th align="center">Profit<br/>(billions <br/>US$)
# </th>
# <th align="center">Assets<br/>(billions <br/>US$)
# </th>
# <th align="center">Value<br/>(billions <br/>US$)
# </th>
# <th align="center">Industry
# </th></tr>
# <tr>
# <td>1
# </td>
# <td>261
# </td>
# <td align="left"><a href="/wiki/Anglo_American_plc" title="Anglo American plc">Anglo American</a>
# </td>
# <td align="left"><a href="/wiki/Johannesburg" title="Johannesburg">Johannesburg</a>*
# </td>
# <td>27.6
# </td>
# <td>3.6
# </td>
# <td>52.2
# </td>
# <td>35.9
# </td>
# <td align="left">Diversified Metals &amp; Mining
# </td></tr>
# <tr>
# <td>2
# </td>
# <td>415
# </td>
# ...

# %%
soup.find_all('table')
# Out:
# [<table class="wikitable sortable" style="text-align:center;">
#  <tbody><tr>
#  <th><br/><br/><br/>
#  </th>
#  <th align="center">Forbes <br/>2000 rank
#  </th>
#  <th align="center">Name
#  </th>
#  <th align="center">Headquarters
#  </th>
#  <th align="center">Revenue<br/>(billions <br/>US$)
#  </th>
#  <th align="center">Profit<br/>(billions <br/>US$)
#  </th>
#  <th align="center">Assets<br/>(billions <br/>US$)
#  </th>
#  <th align="center">Value<br/>(billions <br/>US$)
#  </th>
#  <th align="center">Industry
#  </th></tr>
#  <tr>
#  <td>1
#  </td>
#  <td>261
#  </td>
#  <td align="left"><a href="/wiki/Anglo_American_plc" title="Anglo American plc">Anglo American</a>
#  </td>
#  <td align="left"><a href="/wiki/Johannesburg" title="Johannesburg">Johannesburg</a>*
#  </td>
#  <td>27.6
#  </td>
#  <td>3.6
#  </td>
#  <td>52.2
#  </td>
#  <td>35.9
#  </td>
#  <td align="left">Diversified Metals &amp; Mining
#  </td></tr>
#  <tr>
#  <td>2
#  </td>
#  <td>415
#  </td>
# ...

# %%
#saving html code to table
soup.find('table', class_='wikitable sortable')
# Out:
# <table class="wikitable sortable" style="text-align:center;">
# <tbody><tr>
# <th><br/><br/><br/>
# </th>
# <th align="center">Forbes <br/>2000 rank
# </th>
# <th align="center">Name
# </th>
# <th align="center">Headquarters
# </th>
# <th align="center">Revenue<br/>(billions <br/>US$)
# </th>
# <th align="center">Profit<br/>(billions <br/>US$)
# </th>
# <th align="center">Assets<br/>(billions <br/>US$)
# </th>
# <th align="center">Value<br/>(billions <br/>US$)
# </th>
# <th align="center">Industry
# </th></tr>
# <tr>
# <td>1
# </td>
# <td>261
# </td>
# <td align="left"><a href="/wiki/Anglo_American_plc" title="Anglo American plc">Anglo American</a>
# </td>
# <td align="left"><a href="/wiki/Johannesburg" title="Johannesburg">Johannesburg</a>*
# </td>
# <td>27.6
# </td>
# <td>3.6
# </td>
# <td>52.2
# </td>
# <td>35.9
# </td>
# <td align="left">Diversified Metals &amp; Mining
# </td></tr>
# <tr>
# <td>2
# </td>
# <td>415
# </td>
# ...

# %%
#saving the html code under table
table = soup.find_all('table')
table
# Out:
# [<table class="wikitable sortable" style="text-align:center;">
#  <tbody><tr>
#  <th><br/><br/><br/>
#  </th>
#  <th align="center">Forbes <br/>2000 rank
#  </th>
#  <th align="center">Name
#  </th>
#  <th align="center">Headquarters
#  </th>
#  <th align="center">Revenue<br/>(billions <br/>US$)
#  </th>
#  <th align="center">Profit<br/>(billions <br/>US$)
#  </th>
#  <th align="center">Assets<br/>(billions <br/>US$)
#  </th>
#  <th align="center">Value<br/>(billions <br/>US$)
#  </th>
#  <th align="center">Industry
#  </th></tr>
#  <tr>
#  <td>1
#  </td>
#  <td>261
#  </td>
#  <td align="left"><a href="/wiki/Anglo_American_plc" title="Anglo American plc">Anglo American</a>
#  </td>
#  <td align="left"><a href="/wiki/Johannesburg" title="Johannesburg">Johannesburg</a>*
#  </td>
#  <td>27.6
#  </td>
#  <td>3.6
#  </td>
#  <td>52.2
#  </td>
#  <td>35.9
#  </td>
#  <td align="left">Diversified Metals &amp; Mining
#  </td></tr>
#  <tr>
#  <td>2
#  </td>
#  <td>415
#  </td>
# ...

# %%
#extracting the title names
top_titles = soup.find_all('th')

# %%
table_title = [title.text.strip() for title in top_titles]
top_titles
# Out:
# [<th><br/><br/><br/>
#  </th>,
#  <th align="center">Forbes <br/>2000 rank
#  </th>,
#  <th align="center">Name
#  </th>,
#  <th align="center">Headquarters
#  </th>,
#  <th align="center">Revenue<br/>(billions <br/>US$)
#  </th>,
#  <th align="center">Profit<br/>(billions <br/>US$)
#  </th>,
#  <th align="center">Assets<br/>(billions <br/>US$)
#  </th>,
#  <th align="center">Value<br/>(billions <br/>US$)
#  </th>,
#  <th align="center">Industry
#  </th>]

# %%
#retrieving data in rows
for x in raw_data[1:]:
    data = x.find_all('td')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #retrieving data in rows
# ----> 2 for x in raw_data[1:]:
#       3     data = x.find_all('td')
#
# NameError: name 'raw_data' is not defined
